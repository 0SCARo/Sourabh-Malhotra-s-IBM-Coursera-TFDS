# %% [markdown]
# <h2> My Jupyter Notebook on IBM Watson Studio (I am using Jupyterlab, instead). <h2>

# %% [markdown]
# <h5> Sourabh Malhotra <h5>

# %% [markdown]
# <em> I am interested in Data Science becuase I love to gain insights from data. <em>

# %% [markdown]
# <h3> The following code is simple multiplication <h3>

# %%
7*8
# Out:
# 56

# %% [markdown]
# ***
#
# |<em>Markdown<em>|<em>Less<em>|<em>Pretty<em>|
# |--------|----|------|
# |<em>still<em>|renders|<b>nicely<b>|
# |1|2|3|
#
# - one
# - two
# - three
# - four
# - five
# - six
